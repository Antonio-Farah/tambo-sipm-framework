# %% [markdown]
# # 08 - Final cleaned HDF5 Panel A vs CORSIKA digitized readout matching
#
# This notebook copies the final cleaned matching workflow from notebook 07 and adds an explicit simulated readout layer:
#
# analog SiPM response -> 8 ns sampling -> 14-bit ADC digitization.
#
# The real HDF5 pulses are already measured by the DAQ, so the final comparison is measured HDF5 real pulses versus CORSIKA-derived simulated pulses after the same readout representation.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

DATA_CORSIKA = PROJECT_ROOT / "data/raw/corsika/DATA_PROCESADA_ANTONIO_ROMERO.csv"
DATA_H5_PANEL_A = PROJECT_ROOT / "data/raw/Test_Panel/03A_040526_1h50m_AMP5_C5_thr0_82.h5"
INPUT_FEATURES = PROJECT_ROOT / "outputs/tables/latest_h5_panel_A_thresholded_pulse_features_all.csv"
OUTPUT_TABLES = PROJECT_ROOT / "outputs/tables"
OUTPUT_FIGURES = PROJECT_ROOT / "outputs/figures"
OUTPUT_TABLES.mkdir(parents=True, exist_ok=True)
OUTPUT_FIGURES.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Input features exists:", INPUT_FEATURES.exists(), INPUT_FEATURES)
print("Panel A HDF5 exists:", DATA_H5_PANEL_A.exists(), DATA_H5_PANEL_A)
print("CORSIKA exists:", DATA_CORSIKA.exists(), DATA_CORSIKA)
# Out:
# Project root: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework
# Input features exists: True c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\tables\latest_h5_panel_A_thresholded_pulse_features_all.csv
# Panel A HDF5 exists: True c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\data\raw\Test_Panel\03A_040526_1h50m_AMP5_C5_thr0_82.h5
# CORSIKA exists: True c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\data\raw\corsika\DATA_PROCESADA_ANTONIO_ROMERO.csv

# %%
import copy
import json
from bisect import bisect_left

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Markdown, display
from matplotlib.colors import LogNorm

try:
    from scipy.stats import ks_2samp
except Exception:
    ks_2samp = None

from tambo_sipm import load_simulation_config
from tambo_sipm.io import (
    build_photon_events,
    detector_summary,
    load_romero_photon_table,
    load_test_panel_h5_samples,
)
from tambo_sipm.simulation import build_calibration_config
from tambo_sipm.simulation.batch import simulate_feature_row_from_photon_event
from tambo_sipm.detector import simulate_detector_event_from_config
from tambo_sipm.plotting import plot_waveform_overlay, save_figure

plt.rcParams["figure.dpi"] = 130
plt.rcParams["savefig.dpi"] = 300
plt.rcParams["font.size"] = 10
print("Imports OK")
# Out:
# Imports OK

# %%
PREFIX = "latest_h5_panel_A_final_digitized"

THRESHOLD_MV = 18.0
MIN_PEAK_MV = 50.0
MAX_PEAK_MV = 900.0
MIN_SAMPLES_ABOVE_THRESHOLD = 3
MIN_WIDTH_NS = 16.0
MAX_WIDTH_NS = 600.0

N_MATCH_TARGET = 20_000
N_SIM_POOL = 100_000
RANDOM_SEED = 42
TEMPORAL_BIN_NS = 8.0
N_OVERLAY_WAVEFORMS = 250

VOLTAGE_SCALE_MV_PER_PE = 0.12
PDE = 0.41
ETA_TRANSPORT = 0.025
TAU_F_NS = 220.0
ARRIVAL_SPREAD_NS = 20.0

FEATURE_THRESHOLD_MV = THRESHOLD_MV
N_PRETRIGGER_SAMPLES = 3

print("Threshold for pulse boundaries [mV]:", THRESHOLD_MV)
print("Minimum peak cut [mV]:", MIN_PEAK_MV)
print("Saturation exclusion peak >= [mV]:", MAX_PEAK_MV)
print("Target matched clean pulses:", N_MATCH_TARGET)
print("Simulated pool target:", N_SIM_POOL)
print("Temporal bin size [ns]:", TEMPORAL_BIN_NS)
# Out:
# Threshold for pulse boundaries [mV]: 18.0
# Minimum peak cut [mV]: 50.0
# Saturation exclusion peak >= [mV]: 900.0
# Target matched clean pulses: 20000
# Simulated pool target: 100000
# Temporal bin size [ns]: 8.0

# %% [markdown]
# ## 1. Load thresholded real-pulse diagnostics
#
# The table below comes from notebook 06. It contains all gap-segmented candidate windows, including invalid candidates, so the final cutflow is explicit and reproducible.

# %%
if not INPUT_FEATURES.exists():
    raise FileNotFoundError(
        f"Missing {INPUT_FEATURES}. Run notebook 06 before running this final notebook."
    )

features = pd.read_csv(INPUT_FEATURES)
print("Feature rows loaded:", len(features))
print("Columns:", list(features.columns))
display(features.head())
display(features[["peak_mV", "width_ns", "integral_mVns", "snr_peak", "baseline_rms_mV"]].describe())
# Out:
# Feature rows loaded: 426568
# Columns: ['candidate_id', 'event_id', 'row_start', 'row_end', 'candidate_start_time_ns', 'candidate_end_time_ns', 'n_samples_candidate', 'source_file', 'panel', 'run_id', 'acquisition_date', 'acquisition_duration', 'threshold_token', 'baseline_mV', 'baseline_rms_mV', 'baseline_method', 'threshold_mV', 'peak_mV', 'snr_peak', 'n_samples_above_threshold', 'valid_threshold_pulse', 'threshold_start_time_ns', 'threshold_end_time_ns', 'threshold_start_sample_index', 'threshold_end_sample_index', 'width_ns', 'integral_mVns', 'rms_mV', 'n_samples_thresholded', 'peak_index_in_candidate']
#    candidate_id                      event_id  row_start  row_end  \
# 0             0  threshold_candidate_A_000000          0       24
# 1             1  threshold_candidate_A_000001         25       49
# 2             2  threshold_candidate_A_000002         50       81
# 3             3  threshold_candidate_A_000003         82      120
# 4             4  threshold_candidate_A_000004        121      161
#
#    candidate_start_time_ns  candidate_end_time_ns  n_samples_candidate  \
# 0                6881208.0              6881400.0                   25
# 1               29659584.0             29659776.0                   25
# 2               32668448.0             32668696.0                   32
# 3               34656616.0             34656920.0                   39
# 4               47076712.0             47077032.0                   41
#
#                            source_file panel run_id  ...  \
# 0  03A_040526_1h50m_AMP5_C5_thr0_82.h5     A    03A  ...
# 1  03A_040526_1h50m_AMP5_C5_thr0_82.h5     A    03A  ...
# 2  03A_040526_1h50m_AMP5_C5_thr0_82.h5     A    03A  ...
# 3  03A_040526_1h50m_AMP5_C5_thr0_82.h5     A    03A  ...
# 4  03A_040526_1h50m_AMP5_C5_thr0_82.h5     A    03A  ...
#
#   valid_threshold_pulse threshold_start_time_ns threshold_end_time_ns  \
# 0                 False                     NaN                   NaN
# 1                 False                     NaN                   NaN
# 2                 False                     NaN                   NaN
# 3                  True                    32.0                  72.0
# 4                 False                     NaN                   NaN
#
#    threshold_start_sample_index  threshold_end_sample_index width_ns  \
# 0                           NaN                         NaN      NaN
# 1                           NaN                         NaN      NaN
# 2                           NaN                         NaN      NaN
# 3                          86.0                        91.0     40.0
# 4                           NaN                         NaN      NaN
#
#    integral_mVns     rms_mV  n_samples_thresholded  peak_index_in_candidate
# 0            NaN        NaN                      0                        5
# 1            NaN        NaN                      0                        3
# 2            NaN        NaN                      0                        5
# 3        805.688  19.905762                      6                        5
# 4            NaN        NaN                      0                        8
#
# [5 rows x 30 columns]
# c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\.venv\Lib\site-packages\pandas\core\nanops.py:1028: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#              peak_mV       width_ns  integral_mVns      snr_peak  \
# count  426568.000000  170329.000000  170329.000000  4.265680e+05
# mean       20.176367      69.711347    2322.807417           inf
# std        18.461214      59.670832    5220.021372           NaN
# min         0.366000       0.000000       0.000000  6.744908e-01
# 25%        12.444000      24.000000     470.920000  5.452134e+00
# 50%        15.982000      56.000000    1321.504000  7.840955e+00
# 75%        22.570000     104.000000    2743.066050  1.059914e+01
# max       996.862000    1056.000000  454438.288000           inf
#
#        baseline_rms_mV
# count    426568.000000
# mean          6.117818
# std          13.913417
# min           0.000000
# 25%           1.627895
# 50%           2.260965
# 75%           3.255790
# max         492.619054

# %% [markdown]
# ## 2. Real-pulse cutflow
#
# The final clean sample applies the requested thresholded-pulse criteria. `snr_peak` and `baseline_rms_mV` are kept only as diagnostics because the previous notebook showed suspicious SNR behavior.

# %%
def cutflow_row(step, mask):
    kept = int(mask.sum())
    return {
        "step": step,
        "n_pulses": kept,
        "removed_from_previous": np.nan,
        "retained_fraction_of_all": kept / len(features) if len(features) else np.nan,
    }

all_mask = pd.Series(True, index=features.index)
valid_mask = all_mask & (features["valid_threshold_pulse"] == True)
min_peak_mask = valid_mask & (features["peak_mV"] >= MIN_PEAK_MV)
saturation_mask = min_peak_mask & (features["peak_mV"] < MAX_PEAK_MV)
min_samples_mask = saturation_mask & (features["n_samples_above_threshold"] >= MIN_SAMPLES_ABOVE_THRESHOLD)
width_mask = min_samples_mask & (features["width_ns"] >= MIN_WIDTH_NS) & (features["width_ns"] <= MAX_WIDTH_NS)
final_mask = width_mask & (features["integral_mVns"] > 0)

cutflow = pd.DataFrame([
    cutflow_row("all candidates", all_mask),
    cutflow_row("valid threshold pulses", valid_mask),
    cutflow_row("after minimum peak", min_peak_mask),
    cutflow_row("after saturation removal", saturation_mask),
    cutflow_row("after minimum samples above threshold", min_samples_mask),
    cutflow_row("after width range", width_mask),
    cutflow_row("final clean real sample", final_mask),
])
cutflow["removed_from_previous"] = cutflow["n_pulses"].shift(1) - cutflow["n_pulses"]
cutflow.loc[0, "removed_from_previous"] = 0
cutflow.to_csv(OUTPUT_TABLES / f"{PREFIX}_real_selection_cutflow.csv", index=False)
display(cutflow)

real_clean = features[
    (features["valid_threshold_pulse"] == True)
    & (features["peak_mV"] >= MIN_PEAK_MV)
    & (features["peak_mV"] < MAX_PEAK_MV)
    & (features["n_samples_above_threshold"] >= MIN_SAMPLES_ABOVE_THRESHOLD)
    & (features["width_ns"] >= MIN_WIDTH_NS)
    & (features["width_ns"] <= MAX_WIDTH_NS)
    & (features["integral_mVns"] > 0)
].copy().reset_index(drop=True)
real_clean["match_peak_mV"] = pd.to_numeric(real_clean["peak_mV"], errors="coerce")

print("Clean HDF5 Panel A pulses available after all agreed cuts:", len(real_clean))
print("The final matched sample will be selected after simulated valid CORSIKA pulses are known.")
display(real_clean[["event_id", "peak_mV", "width_ns", "integral_mVns", "n_samples_above_threshold", "snr_peak", "baseline_rms_mV"]].head())
display(real_clean[["peak_mV", "width_ns", "integral_mVns", "rms_mV", "snr_peak", "baseline_rms_mV"]].describe())
# Out:
#                                     step  n_pulses  removed_from_previous  \
# 0                         all candidates    426568                    0.0
# 1                 valid threshold pulses    170329               256239.0
# 2                     after minimum peak     14536               155793.0
# 3               after saturation removal     14519                   17.0
# 4  after minimum samples above threshold     14519                    0.0
# 5                      after width range     14505                   14.0
# 6                final clean real sample     14505                    0.0
#
#    retained_fraction_of_all
# 0                  1.000000
# 1                  0.399301
# 2                  0.034077
# 3                  0.034037
# 4                  0.034037
# 5                  0.034004
# 6                  0.034004
# Clean HDF5 Panel A pulses available after all agreed cuts: 14505
# The final matched sample will be selected after simulated valid CORSIKA pulses are known.
#                        event_id  peak_mV  width_ns  integral_mVns  \
# 0  threshold_candidate_A_000023   64.050     224.0    9069.480001
# 1  threshold_candidate_A_000033   66.185     192.0    7982.703999
# 2  threshold_candidate_A_000038   51.606     176.0    6584.095999
# 3  threshold_candidate_A_000048   62.952     200.0    7749.928003
# 4  threshold_candidate_A_000062   50.020     176.0    6437.696000
#
#    n_samples_above_threshold   snr_peak  baseline_rms_mV
# 0                         29  12.646702         5.064562
# 1                         25  17.849329         3.707983
# 2                         23  14.265480         3.617544
# 3                         26  15.819874         3.979298
# 4                         23  17.283826         2.894035
#             peak_mV      width_ns  integral_mVns        rms_mV      snr_peak  \
# count  14505.000000  14505.000000   14505.000000  14505.000000  14505.000000
# mean      82.259667    192.798621   10645.929609     54.851537      9.051235
# std       53.525933     53.506681    9150.976728     29.957072      9.304919
# min       50.020000     16.000000     770.064000     33.645004      0.688575
# 25%       55.754000    160.000000    6413.296000     39.946093      1.036622
# 50%       65.453000    184.000000    8078.840000     45.461110      1.865907
# 75%       86.132000    224.000000   11433.840000     57.397791     15.995067
# max      846.253000    512.000000  195798.288000    512.321994     88.235655
#
#        baseline_rms_mV
# count     14505.000000
# mean         44.666873
# std          47.476040
# min           0.904386
# 25%           3.979298
# 50%          48.384651
# 75%          72.622196
# max         492.619054

# %% [markdown]
# ## 3. Load CORSIKA photon events
#
# This uses the existing project pipeline. As in the exploratory HDF5 notebooks, all available CORSIKA detectors are used here as an exploratory simulation pool unless a later physics review restricts the detector choice.

# %%
corsika_table = load_romero_photon_table(DATA_CORSIKA)
print("Detector summary:")
display(detector_summary(corsika_table))

available_detectors = sorted(corsika_table["Detector"].dropna().astype(int).unique())
print("Available detectors:", available_detectors)
print("Exploratory note: using all CORSIKA detectors for the simulated pool.")

def build_all_detector_events(corsika_dataframe):
    event_tables = []
    for detector in available_detectors:
        events = build_photon_events(corsika_dataframe, detector=int(detector)).copy()
        events["detector"] = int(detector)
        if "source_row" in events.columns:
            events["event_id"] = [f"corsika_d{int(detector)}_row{int(row)}" for row in events["source_row"]]
        else:
            events["event_id"] = [f"corsika_d{int(detector)}_idx{idx}" for idx in range(len(events))]
        event_tables.append(events)
    return pd.concat(event_tables, ignore_index=True)

corsika_events_all = build_all_detector_events(corsika_table)
print("CORSIKA events using all detectors:", len(corsika_events_all))
display(corsika_events_all.head())
display(corsika_events_all["detector"].value_counts().sort_index())
corsika_events_all.to_csv(OUTPUT_TABLES / f"{PREFIX}_corsika_all_detectors_events.csv", index=False)
# Out:
# Detector summary:
#    Detector   rows  unique_showers  total_photons  mean_photons  \
# 0       0.0  26777            9862      763901469  28528.269373
# 1       1.0   6616            4737       90889255  13737.795496
# 2       2.0   6472            4632       82816395  12796.105532
# 3       3.0   6417            4508       87813188  13684.461275
#
#    median_photons  min_photons  max_photons
# 0          5387.0          949     18807617
# 1          3327.5          949      2946734
# 2          3287.5          950      2508031
# 3          3359.0          949      1897897
# Available detectors: [np.int64(0), np.int64(1), np.int64(2), np.int64(3)]
# Exploratory note: using all CORSIKA detectors for the simulated pool.
# CORSIKA events using all detectors: 46282
#            event_id  source_row  detector  shower  particle_id particle_name  \
# 0   corsika_d0_row2           2         0      18            1         gamma
# 1   corsika_d0_row6           6         0      56            6           mu-
# 2   corsika_d0_row8           8         0      63            1         gamma
# 3  corsika_d0_row10          10         0      68            1         gamma
# 4  corsika_d0_row11          11         0      71            1         gamma
#
#   particle_category  generated_photons  n_hits particle_name_original  \
# 0   electromagnetic              63228       1                  foton
# 1            muonic              17156       1                  muon-
# 2   electromagnetic               2527       1                  foton
# 3   electromagnetic               2613       1                  foton
# 4   electromagnetic               2079       1                  foton
#
#           t         x         y        ek  carga  masa_MeV  \
# 0  2.669530  0.250841  0.125899  474.3080      0      0.00
# 1  4.166519 -0.225720 -0.097985  930.5940     -1    105.66
# 2  2.351932  0.406301 -0.186175   18.1535      0      0.00
# 3  6.082793 -0.707285 -0.190728   19.0195      0      0.00
# 4  4.841286 -0.471563  0.054370   13.6359      0      0.00
#
#    energia_detectada_poli_MeV  tiempo_deteccion
# 0                    7.903448          5.440774
# 1                    2.144515          8.491790
# 2                    0.315862          4.793476
# 3                    0.326669         12.397351
# 4                    0.259903          9.867033
# detector
# 0    26777
# 1     6616
# 2     6472
# 3     6417
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Simulation configuration
#
# The fixed methodology parameters are preserved:
#
# - `voltage_scale_mV_per_pe = 0.12`
# - `pde = 0.41`
#
# The effective/tuned parameters are applied only to the copied in-notebook config object, not to any YAML file.

# %%
base_config = load_simulation_config()
matched_config = build_calibration_config(
    copy.deepcopy(base_config),
    transport_efficiency=ETA_TRANSPORT,
    tau_f_ns=TAU_F_NS,
    arrival_spread_ns=ARRIVAL_SPREAD_NS,
)

assert matched_config["voltage_conversion"]["voltage_scale_mV_per_pe"] == VOLTAGE_SCALE_MV_PER_PE
assert matched_config["photon_transport"]["pde"] == PDE

print("Fixed voltage_scale_mV_per_pe:", matched_config["voltage_conversion"]["voltage_scale_mV_per_pe"])
print("Fixed PDE:", matched_config["photon_transport"]["pde"])
print("transport_efficiency:", matched_config["photon_transport"]["transport_efficiency"])
print("tau_f_ns:", matched_config["sipm_response"]["tau_f_ns"])
print("arrival_spread_ns:", matched_config["sipm_response"]["arrival_spread_ns"])
# Out:
# Fixed voltage_scale_mV_per_pe: 0.12
# Fixed PDE: 0.41
# transport_efficiency: 0.025
# tau_f_ns: 220.0
# arrival_spread_ns: 20.0

# %% [markdown]
# ## 5. Generate simulated feature pool
#
# `N_SIM_POOL = 100000` is configurable at the top of the notebook. If the CORSIKA event table contains fewer unique photon events than requested, events are sampled with replacement but each detector simulation receives a unique random seed.

# %%
def simulate_feature_pool_with_seeds(photon_events, config, n_events=100_000, random_seed=42, threshold_mV=18.0, n_pretrigger_samples=3):
    replace = n_events > len(photon_events)
    selected_events = photon_events.sample(n=n_events, replace=replace, random_state=random_seed).reset_index(drop=True)
    rows = []
    for local_index, (_, event_row) in enumerate(selected_events.iterrows()):
        simulation_seed = int(random_seed * 1_000_000 + local_index)
        rng = np.random.default_rng(simulation_seed)
        feature_row = simulate_feature_row_from_photon_event(
            event_row=event_row,
            config=config,
            threshold_mV=threshold_mV,
            n_pretrigger_samples=n_pretrigger_samples,
            rng=rng,
        )
        feature_row["simulation_seed"] = simulation_seed
        feature_row["pool_local_index"] = local_index
        feature_row["source_corsika_event_id"] = str(event_row.get("event_id", local_index))
        feature_row["event_id"] = f"sim_pool_{local_index:06d}"
        rows.append(feature_row)
    return pd.DataFrame(rows)

sim_pool_features = simulate_feature_pool_with_seeds(
    photon_events=corsika_events_all,
    config=matched_config,
    n_events=N_SIM_POOL,
    random_seed=RANDOM_SEED,
    threshold_mV=FEATURE_THRESHOLD_MV,
    n_pretrigger_samples=N_PRETRIGGER_SAMPLES,
)

sim_quality = (
    np.isfinite(pd.to_numeric(sim_pool_features["peak_mV"], errors="coerce"))
    & np.isfinite(pd.to_numeric(sim_pool_features["integral_mVns"], errors="coerce"))
    & np.isfinite(pd.to_numeric(sim_pool_features["width_ns"], errors="coerce"))
    & (pd.to_numeric(sim_pool_features["peak_mV"], errors="coerce") < MAX_PEAK_MV)
    & (pd.to_numeric(sim_pool_features["integral_mVns"], errors="coerce") > 0)
    & (pd.to_numeric(sim_pool_features["width_ns"], errors="coerce") > 0)
)
sim_valid = sim_pool_features[sim_quality].copy().reset_index(drop=True)
sim_valid["match_peak_mV"] = pd.to_numeric(sim_valid["peak_mV"], errors="coerce")

print("Simulated pool rows:", len(sim_pool_features))
print("Simulated valid rows after equivalent quality filters:", len(sim_valid))
display(sim_valid[["event_id", "detector", "generated_photons", "peak_mV", "width_ns", "integral_mVns", "simulation_seed"]].head())
display(sim_valid[["peak_mV", "width_ns", "integral_mVns", "rms_mV"]].describe())

sim_pool_features.to_csv(OUTPUT_TABLES / f"{PREFIX}_sim_pool_features_all.csv", index=False)
sim_valid.to_csv(OUTPUT_TABLES / f"{PREFIX}_sim_pool_features_valid.csv", index=False)
# Out:
# Simulated pool rows: 100000
# Simulated valid rows after equivalent quality filters: 9886
#           event_id  detector  generated_photons    peak_mV  width_ns  \
# 0  sim_pool_000000         0              65124  34.790039      88.0
# 1  sim_pool_000006         0              52585  33.813477      88.0
# 2  sim_pool_000014         0              51141  30.639648      80.0
# 3  sim_pool_000024         0              28292  19.409180      24.0
# 4  sim_pool_000027         0              77390  42.602539      96.0
#
#    integral_mVns  simulation_seed
# 0    2480.957031         42000000
# 1    2419.433594         42000006
# 2    2099.609375         42000014
# 3     455.566406         42000024
# 4    3148.437500         42000027
#            peak_mV     width_ns  integral_mVns       rms_mV
# count  9886.000000  9886.000000    9886.000000  9886.000000
# mean     59.196705    89.936476    5262.271487    43.386538
# std      70.463056    52.621845    8184.590911    44.744277
# min      18.066406     8.000000     144.531250    18.066406
# 25%      22.338867    48.000000     951.904297    20.723103
# 50%      33.203125    88.000000    2414.550781    27.236014
# 75%      61.767578   136.000000    5862.670898    43.816087
# max     522.094727   192.000000   57734.863281   329.080813

# %% [markdown]
# ## 6. One-to-one peak matching without replacement
#
# The primary final matching uses peak only. This controls amplitude so that the remaining plots focus on morphology: integral, width, RMS, and waveform shape.

# %%
def greedy_peak_match_without_replacement(real_df, sim_df, peak_column="match_peak_mV"):
    real_sorted = real_df.reset_index(names="real_original_index").sort_values(peak_column).reset_index(drop=True)
    sim_sorted = sim_df.reset_index(names="sim_original_index").sort_values(peak_column).reset_index(drop=True)
    available_positions = list(range(len(sim_sorted)))
    available_peaks = sim_sorted[peak_column].to_numpy(dtype=float).tolist()

    match_rows = []
    selected_sim_positions = []

    for match_id, real_row in real_sorted.iterrows():
        real_peak = float(real_row[peak_column])
        insertion = bisect_left(available_peaks, real_peak)
        candidate_indices = []
        if insertion < len(available_peaks):
            candidate_indices.append(insertion)
        if insertion > 0:
            candidate_indices.append(insertion - 1)
        if not candidate_indices:
            raise RuntimeError("No simulated candidates remain during matching.")

        best_local_index = min(candidate_indices, key=lambda idx: abs(available_peaks[idx] - real_peak))
        sim_peak = float(available_peaks.pop(best_local_index))
        best_global_position = available_positions.pop(best_local_index)
        sim_row = sim_sorted.iloc[best_global_position]
        selected_sim_positions.append(best_global_position)

        match_rows.append({
            "match_id": int(match_id),
            "real_original_index": int(real_row["real_original_index"]),
            "sim_original_index": int(sim_row["sim_original_index"]),
            "real_event_id": str(real_row["event_id"]),
            "simulated_event_id": str(sim_row["event_id"]),
            "real_match_peak_mV": real_peak,
            "simulated_match_peak_mV": sim_peak,
            "delta_peak_mV": sim_peak - real_peak,
            "abs_delta_peak_mV": abs(sim_peak - real_peak),
        })

    match_table = pd.DataFrame(match_rows)
    matched_real = real_sorted.copy()
    matched_sim = sim_sorted.iloc[selected_sim_positions].copy().reset_index(drop=True)
    matched_real["match_id"] = match_table["match_id"].to_numpy(dtype=int)
    matched_sim["match_id"] = match_table["match_id"].to_numpy(dtype=int)
    matched_sim["matched_real_event_id"] = match_table["real_event_id"].to_numpy()
    matched_sim["abs_delta_peak_mV"] = match_table["abs_delta_peak_mV"].to_numpy(dtype=float)
    return matched_real, matched_sim, match_table

N_MATCH = min(N_MATCH_TARGET, len(real_clean), len(sim_valid))
if N_MATCH <= 0:
    raise ValueError(
        f"No matchable pulses remain: {len(real_clean)} clean real vs {len(sim_valid)} valid simulated."
    )

if N_MATCH < N_MATCH_TARGET:
    print(
        f"Requested {N_MATCH_TARGET} matched clean pulses, but using {N_MATCH} because "
        f"HDF5 clean = {len(real_clean)} and simulated valid = {len(sim_valid)}."
    )
else:
    print(f"Using requested {N_MATCH} matched clean pulses.")

real_sample = real_clean.sample(n=N_MATCH, random_state=RANDOM_SEED).reset_index(drop=True)
sim_match_pool = sim_valid.sample(n=N_MATCH, random_state=RANDOM_SEED + 1).reset_index(drop=True)

real_sample.to_csv(OUTPUT_TABLES / f"{PREFIX}_real_clean_sample.csv", index=False)
sim_match_pool.to_csv(OUTPUT_TABLES / f"{PREFIX}_sim_valid_sample_for_matching.csv", index=False)

matched_real, matched_sim, peak_match_table = greedy_peak_match_without_replacement(real_sample, sim_match_pool)
print("Matched pairs:", len(peak_match_table))
display(peak_match_table.describe())
display(peak_match_table.head())

matched_real.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_real.csv", index=False)
matched_sim.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_simulated.csv", index=False)
peak_match_table.to_csv(OUTPUT_TABLES / f"{PREFIX}_peak_match_table.csv", index=False)
# Out:
# Requested 20000 matched clean pulses, but using 9886 because HDF5 clean = 14505 and simulated valid = 9886.
# Matched pairs: 9886
#           match_id  real_original_index  sim_original_index  \
# count  9886.000000          9886.000000         9886.000000
# mean   4942.500000          4942.500000         4942.500000
# std    2853.986715          2853.986715         2853.986715
# min       0.000000             0.000000            0.000000
# 25%    2471.250000          2471.250000         2471.250000
# 50%    4942.500000          4942.500000         4942.500000
# 75%    7413.750000          7413.750000         7413.750000
# max    9885.000000          9885.000000         9885.000000
#
#        real_match_peak_mV  simulated_match_peak_mV  delta_peak_mV  \
# count         9886.000000              9886.000000    9886.000000
# mean            81.845161                59.196705     -22.648456
# std             51.950779                70.463056      74.489865
# min             50.020000                18.066406    -828.186594
# 25%             55.937000                22.338867     -53.484133
# 50%             65.514000                33.203125     -24.990875
# 75%             86.132000                61.767578       9.185578
# max            846.253000               522.094727     251.132727
#
#        abs_delta_peak_mV
# count        9886.000000
# mean           52.579517
# std            57.418282
# min             0.028828
# 25%            19.258313
# 50%            39.146812
# 75%            65.359082
# max           828.186594
#    match_id  real_original_index  sim_original_index  \
# 0         0                  272                8424
# 1         1                 3757                2447
# 2         2                 4392                9015
# 3         3                 4438                7220
# 4         4                 2671                5455
#
#                   real_event_id simulated_event_id  real_match_peak_mV  \
# 0  threshold_candidate_A_078245    sim_pool_077799               50.02
# 1  threshold_candidate_A_056007    sim_pool_094924               50.02
# 2  threshold_candidate_A_255434    sim_pool_002068               50.02
# 3  threshold_candidate_A_357138    sim_pool_001641               50.02
# 4  threshold_candidate_A_169217    sim_pool_013230               50.02
#
#    simulated_match_peak_mV  delta_peak_mV  abs_delta_peak_mV
# 0                50.048828       0.028828           0.028828
# 1                50.048828       0.028828           0.028828
# 2                50.048828       0.028828           0.028828
# 3                50.048828       0.028828           0.028828
# 4                50.048828       0.028828           0.028828

# %% [markdown]
# ## 7. Matching summary

# %%
def finite_series(df, column):
    values = pd.to_numeric(df[column], errors="coerce")
    return values[np.isfinite(values)]

def maybe_ks(real_values, sim_values):
    real_values = np.asarray(real_values, dtype=float)
    sim_values = np.asarray(sim_values, dtype=float)
    real_values = real_values[np.isfinite(real_values)]
    sim_values = sim_values[np.isfinite(sim_values)]
    if ks_2samp is None or len(real_values) == 0 or len(sim_values) == 0:
        return np.nan, np.nan
    result = ks_2samp(real_values, sim_values)
    return float(result.statistic), float(result.pvalue)

peak_ks, peak_ks_p = maybe_ks(matched_real["match_peak_mV"], matched_sim["match_peak_mV"])
integral_ks, integral_ks_p = maybe_ks(matched_real["integral_mVns"], matched_sim["integral_mVns"])
width_ks, width_ks_p = maybe_ks(matched_real["width_ns"], matched_sim["width_ns"])

summary = pd.DataFrame([{
    "n_match_target": N_MATCH_TARGET,
    "n_real_clean": len(real_clean),
    "n_real_used": len(matched_real),
    "match_limiting_sample": "real_clean" if len(real_clean) <= len(sim_valid) else "sim_valid",
    "n_simulated_pool": len(sim_pool_features),
    "n_simulated_valid": len(sim_valid),
    "n_matched": len(matched_real),
    "mean_peak_real_mV": finite_series(matched_real, "match_peak_mV").mean(),
    "median_peak_real_mV": finite_series(matched_real, "match_peak_mV").median(),
    "mean_peak_sim_mV": finite_series(matched_sim, "match_peak_mV").mean(),
    "median_peak_sim_mV": finite_series(matched_sim, "match_peak_mV").median(),
    "mean_integral_real_mVns": finite_series(matched_real, "integral_mVns").mean(),
    "median_integral_real_mVns": finite_series(matched_real, "integral_mVns").median(),
    "mean_integral_sim_mVns": finite_series(matched_sim, "integral_mVns").mean(),
    "median_integral_sim_mVns": finite_series(matched_sim, "integral_mVns").median(),
    "mean_width_real_ns": finite_series(matched_real, "width_ns").mean(),
    "median_width_real_ns": finite_series(matched_real, "width_ns").median(),
    "mean_width_sim_ns": finite_series(matched_sim, "width_ns").mean(),
    "median_width_sim_ns": finite_series(matched_sim, "width_ns").median(),
    "ks_peak_statistic": peak_ks,
    "ks_peak_pvalue": peak_ks_p,
    "ks_integral_statistic": integral_ks,
    "ks_integral_pvalue": integral_ks_p,
    "ks_width_statistic": width_ks,
    "ks_width_pvalue": width_ks_p,
    "mean_abs_delta_peak_mV": peak_match_table["abs_delta_peak_mV"].mean(),
    "median_abs_delta_peak_mV": peak_match_table["abs_delta_peak_mV"].median(),
    "max_abs_delta_peak_mV": peak_match_table["abs_delta_peak_mV"].max(),
    "threshold_mV": THRESHOLD_MV,
    "min_peak_mV": MIN_PEAK_MV,
    "max_peak_mV": MAX_PEAK_MV,
    "temporal_bin_ns": TEMPORAL_BIN_NS,
    "voltage_scale_mV_per_pe": VOLTAGE_SCALE_MV_PER_PE,
    "pde": PDE,
    "transport_efficiency": ETA_TRANSPORT,
    "tau_f_ns": TAU_F_NS,
    "arrival_spread_ns": ARRIVAL_SPREAD_NS,
    "snr_used_as_hard_cut": False,
    "exploratory_all_corsika_detectors": True,
}])
summary.to_csv(OUTPUT_TABLES / f"{PREFIX}_matching_summary.csv", index=False)
display(summary.T)
# Out:
#                                               0
# n_match_target                            20000
# n_real_clean                              14505
# n_real_used                                9886
# match_limiting_sample                 sim_valid
# n_simulated_pool                         100000
# n_simulated_valid                          9886
# n_matched                                  9886
# mean_peak_real_mV                     81.845161
# median_peak_real_mV                      65.514
# mean_peak_sim_mV                      59.196705
# median_peak_sim_mV                    33.203125
# mean_integral_real_mVns            10560.465334
# median_integral_real_mVns              8054.684
# mean_integral_sim_mVns              5262.271487
# median_integral_sim_mVns            2414.550781
# mean_width_real_ns                   192.329354
# median_width_real_ns                      184.0
# mean_width_sim_ns                     89.936476
# median_width_sim_ns                        88.0
# ks_peak_statistic                      0.680154
# ks_peak_pvalue                              0.0
# ks_integral_statistic                  0.655675
# ks_integral_pvalue                          0.0
# ks_width_statistic                     0.629779
# ks_width_pvalue                             0.0
# mean_abs_delta_peak_mV                52.579517
# median_abs_delta_peak_mV              39.146812
# max_abs_delta_peak_mV                828.186594
# threshold_mV                               18.0
# min_peak_mV                                50.0
# max_peak_mV                               900.0
# temporal_bin_ns                             8.0
# voltage_scale_mV_per_pe                    0.12
# pde                                        0.41
# transport_efficiency                      0.025
# tau_f_ns                                  220.0
# arrival_spread_ns                          20.0
# snr_used_as_hard_cut                      False
# exploratory_all_corsika_detectors          True

# %% [markdown]
# ## 8. Normalized 1D histograms
#
# All comparison histograms are normalized. Width uses fixed 8 ns bins.

# %%
def finite_pair(real_df, sim_df, column):
    rv = pd.to_numeric(real_df[column], errors="coerce")
    sv = pd.to_numeric(sim_df[column], errors="coerce")
    mask = np.isfinite(rv) & np.isfinite(sv)
    return rv[mask].to_numpy(dtype=float), sv[mask].to_numpy(dtype=float)

def common_linear_bins(a, b, n_bins=50, lower=None, upper=None):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    values = np.concatenate([a[np.isfinite(a)], b[np.isfinite(b)]])
    if lower is None:
        lower = float(np.min(values))
    if upper is None:
        upper = float(np.max(values))
    if lower == upper:
        upper = lower + 1.0
    return np.linspace(lower, upper, n_bins + 1)

def temporal_bins_8ns(a, b, lower=0.0):
    values = np.concatenate([np.asarray(a, dtype=float), np.asarray(b, dtype=float)])
    values = values[np.isfinite(values)]
    upper = TEMPORAL_BIN_NS * np.ceil(values.max() / TEMPORAL_BIN_NS) + TEMPORAL_BIN_NS
    return np.arange(lower, upper + TEMPORAL_BIN_NS, TEMPORAL_BIN_NS)

def normalized_hist_overlay(real_values, sim_values, bins, xlabel, title, output_name):
    fig, ax = plt.subplots(figsize=(7.2, 4.2))
    ax.hist(real_values, bins=bins, density=True, histtype="step", linewidth=2.0, label="Final cleaned HDF5 Panel A")
    ax.hist(sim_values, bins=bins, density=True, histtype="step", linewidth=2.0, label="Peak-matched simulation")
    ax.set_xlabel(xlabel)
    ax.set_ylabel("Normalized density")
    ax.set_title(title)
    ax.legend()
    ax.grid(alpha=0.25)
    save_figure(fig, OUTPUT_FIGURES / output_name)
    plt.show()

real_peak, sim_peak = finite_pair(matched_real, matched_sim, "match_peak_mV")
normalized_hist_overlay(
    real_peak,
    sim_peak,
    common_linear_bins(real_peak, sim_peak, n_bins=60, lower=MIN_PEAK_MV, upper=MAX_PEAK_MV),
    "Peak [mV]",
    "Normalized peak: Final cleaned HDF5 Panel A vs Peak-matched simulation",
    f"{PREFIX}_hist_peak_normalized.png",
)

for column, xlabel, output_name in [
    ("integral_mVns", "Integral [mV ns]", f"{PREFIX}_hist_integral_normalized.png"),
    ("rms_mV", "RMS [mV]", f"{PREFIX}_hist_rms_normalized.png"),
]:
    real_values, sim_values = finite_pair(matched_real, matched_sim, column)
    bins = common_linear_bins(real_values, sim_values, n_bins=60)
    normalized_hist_overlay(
        real_values,
        sim_values,
        bins,
        xlabel,
        f"Normalized {column}: Final cleaned HDF5 Panel A vs Peak-matched simulation",
        output_name,
    )

real_width, sim_width = finite_pair(matched_real, matched_sim, "width_ns")
normalized_hist_overlay(
    real_width,
    sim_width,
    temporal_bins_8ns(real_width, sim_width),
    "Width [ns]",
    "Normalized width: Final cleaned HDF5 Panel A vs Peak-matched simulation",
    f"{PREFIX}_hist_width_8ns_normalized.png",
)

# %% [markdown]
# ## 9. Normalized 2D histograms
#
# The color scale is normalized by the number of entries in each panel. Width axes use fixed 8 ns bins.

# %%
def normalized_hist2d(ax, x, y, x_bins, y_bins, title, xlabel, ylabel):
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    mask = np.isfinite(x) & np.isfinite(y)
    weights = np.ones(mask.sum(), dtype=float) / mask.sum() if mask.sum() else None
    hist = ax.hist2d(
        x[mask],
        y[mask],
        bins=[x_bins, y_bins],
        weights=weights,
        norm=LogNorm(),
        cmap="viridis",
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    return hist

def side_by_side_hist2d(real_df, sim_df, x_column, y_column, x_bins, y_bins, xlabel, ylabel, output_name, subtitle=""):
    fig, axes = plt.subplots(1, 2, figsize=(12.2, 4.8), constrained_layout=True)
    h0 = normalized_hist2d(
        axes[0],
        pd.to_numeric(real_df[x_column], errors="coerce"),
        pd.to_numeric(real_df[y_column], errors="coerce"),
        x_bins,
        y_bins,
        "Final cleaned HDF5 Panel A" + subtitle,
        xlabel,
        ylabel,
    )
    h1 = normalized_hist2d(
        axes[1],
        pd.to_numeric(sim_df[x_column], errors="coerce"),
        pd.to_numeric(sim_df[y_column], errors="coerce"),
        x_bins,
        y_bins,
        "Peak-matched simulation" + subtitle,
        xlabel,
        ylabel,
    )
    fig.colorbar(h1[3], ax=axes, label="Normalized bin fraction")
    save_figure(fig, OUTPUT_FIGURES / output_name)
    plt.show()

peak_bins = common_linear_bins(matched_real["match_peak_mV"], matched_sim["match_peak_mV"], n_bins=50, lower=MIN_PEAK_MV, upper=MAX_PEAK_MV)
integral_bins = common_linear_bins(matched_real["integral_mVns"], matched_sim["integral_mVns"], n_bins=50)
width_bins = temporal_bins_8ns(matched_real["width_ns"], matched_sim["width_ns"])

side_by_side_hist2d(
    matched_real,
    matched_sim,
    "match_peak_mV",
    "integral_mVns",
    peak_bins,
    integral_bins,
    "Peak [mV]",
    "Integral [mV ns]",
    f"{PREFIX}_hist2d_integral_vs_peak_normalized.png",
)

side_by_side_hist2d(
    matched_real,
    matched_sim,
    "width_ns",
    "integral_mVns",
    width_bins,
    integral_bins,
    "Width [ns]",
    "Integral [mV ns]",
    f"{PREFIX}_hist2d_integral_vs_width_8ns_normalized.png",
)

def percentile_bins(real_df, sim_df, column, n_bins=50, temporal=False):
    values = pd.concat([
        pd.to_numeric(real_df[column], errors="coerce"),
        pd.to_numeric(sim_df[column], errors="coerce"),
    ])
    values = values[np.isfinite(values)]
    lo, hi = values.quantile([0.05, 0.95])
    if temporal:
        lo = TEMPORAL_BIN_NS * np.floor(lo / TEMPORAL_BIN_NS)
        hi = TEMPORAL_BIN_NS * np.ceil(hi / TEMPORAL_BIN_NS)
        return np.arange(lo, hi + TEMPORAL_BIN_NS, TEMPORAL_BIN_NS)
    return np.linspace(float(lo), float(hi), n_bins + 1)

side_by_side_hist2d(
    matched_real,
    matched_sim,
    "match_peak_mV",
    "integral_mVns",
    percentile_bins(matched_real, matched_sim, "match_peak_mV", n_bins=50),
    percentile_bins(matched_real, matched_sim, "integral_mVns", n_bins=50),
    "Peak [mV]",
    "Integral [mV ns]",
    f"{PREFIX}_hist2d_integral_vs_peak_p5_p95_normalized.png",
    subtitle=" p5-p95",
)

side_by_side_hist2d(
    matched_real,
    matched_sim,
    "width_ns",
    "integral_mVns",
    percentile_bins(matched_real, matched_sim, "width_ns", temporal=True),
    percentile_bins(matched_real, matched_sim, "integral_mVns", n_bins=50),
    "Width [ns]",
    "Integral [mV ns]",
    f"{PREFIX}_hist2d_integral_vs_width_8ns_p5_p95_normalized.png",
    subtitle=" p5-p95",
)

# %% [markdown]
# ## 10. Waveform overlays
#
# The real overlay is drawn directly from the HDF5 samples using the selected clean candidate windows and the local baseline from notebook 06. The simulated overlay is reconstructed from the stored simulation seeds.

# %%
def selected_waveform_rows(df, n=N_OVERLAY_WAVEFORMS):
    if len(df) <= n:
        return df.copy()
    return df.sample(n=n, random_state=RANDOM_SEED).copy()

overlay_real_rows = selected_waveform_rows(matched_real)
print("Loading HDF5 samples for real waveform overlay...")
samples_A = load_test_panel_h5_samples(DATA_H5_PANEL_A, voltage_unit="auto")

def real_waveform_from_row(row, samples):
    start = int(row["row_start"])
    end = int(row["row_end"])
    candidate = samples.iloc[start : end + 1]
    t = candidate["time_ns"].to_numpy(dtype=float)
    v = candidate["voltage_mV"].to_numpy(dtype=float) - float(row["baseline_mV"])
    return t - t[0], v

real_waveforms = [
    real_waveform_from_row(row, samples_A)
    for _, row in overlay_real_rows.iterrows()
]

fig, ax = plt.subplots(figsize=(7.4, 4.4))
plot_waveform_overlay(
    real_waveforms,
    xlabel="Time from candidate start [ns]",
    ylabel="Baseline-subtracted voltage [mV]",
    label="Final cleaned HDF5 Panel A",
    alpha=0.05,
    ax=ax,
)
ax.axhline(THRESHOLD_MV, color="tab:red", linestyle="--", linewidth=1.1, label="18 mV boundary threshold")
ax.set_title("Overlay of selected clean real HDF5 Panel A waveforms")
ax.legend()
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_selected_clean_real_waveforms.png")
plt.show()

def reconstruct_simulated_waveform(row, config):
    rng = np.random.default_rng(int(row["simulation_seed"]))
    result = simulate_detector_event_from_config(
        generated_photons=int(row["generated_photons"]),
        config=config,
        rng=rng,
    )
    return result.sampled_time_ns, result.digitized_voltage_mV

overlay_sim_rows = selected_waveform_rows(matched_sim)
sim_waveforms = [
    reconstruct_simulated_waveform(row, matched_config)
    for _, row in overlay_sim_rows.iterrows()
]

fig, ax = plt.subplots(figsize=(7.4, 4.4))
plot_waveform_overlay(
    sim_waveforms,
    xlabel="Time [ns]",
    ylabel="Voltage [mV]",
    label="Peak-matched simulation",
    alpha=0.05,
    ax=ax,
)
ax.set_title("Overlay of matched simulated waveforms")
ax.legend()
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_matched_simulated_waveforms.png")
plt.show()
# Out:
# Loading HDF5 samples for real waveform overlay...

# %% [markdown]
# ## 11. Final markdown summary

# %%
summary_row = summary.iloc[0].to_dict()
low_amp_count = int(((features["valid_threshold_pulse"] == True) & (features["peak_mV"] < MIN_PEAK_MV)).sum())
saturated_count = int(((features["valid_threshold_pulse"] == True) & (features["peak_mV"] >= MAX_PEAK_MV)).sum())

summary_md = f"""# Latest HDF5 Panel A Final Analysis Summary

## Inputs

- Real feature table: `{INPUT_FEATURES.name}`
- Latest Panel A HDF5 file: `{DATA_H5_PANEL_A.name}`
- CORSIKA table: `{DATA_CORSIKA.name}`

## Selection Criteria

- Pulse boundary threshold: `{THRESHOLD_MV:g} mV` after local baseline subtraction.
- Minimum peak: `{MIN_PEAK_MV:g} mV`.
- Saturation exclusion: `peak_mV < {MAX_PEAK_MV:g} mV`.
- Minimum samples above threshold: `{MIN_SAMPLES_ABOVE_THRESHOLD}`.
- Width range: `{MIN_WIDTH_NS:g}` to `{MAX_WIDTH_NS:g} ns`.
- Positive integral required.
- SNR is not used as a final hard cut; `snr_peak` and `baseline_rms_mV` are diagnostics.

## Pulse Counts

- All candidate windows: `{int(cutflow.loc[cutflow["step"] == "all candidates", "n_pulses"].iloc[0])}`.
- Valid threshold pulses: `{int(cutflow.loc[cutflow["step"] == "valid threshold pulses", "n_pulses"].iloc[0])}`.
- Low-amplitude valid pulses below `{MIN_PEAK_MV:g} mV`: `{low_amp_count}`. These remain a diagnostic population and are excluded only from the final cleaned comparison.
- Saturated or near-saturated valid pulses at/above `{MAX_PEAK_MV:g} mV`: `{saturated_count}`.
- Requested matched-pair target: `{N_MATCH_TARGET}`.
- Final clean real sample available: `{len(real_clean)}`.
- Simulated pool generated: `{len(sim_pool_features)}`.
- Simulated valid candidates after agreed filters: `{len(sim_valid)}`.
- Final matched pairs used: `{len(matched_real)}`.
- Matching uses `min(N_MATCH_TARGET, len(real_clean), len(sim_valid))`, so the smaller valid sample sets the final number of pairs.

## Why 50 mV

`50 mV` is used as a preliminary minimum peak cut because notebook 06 identified the region below this scale as a low-amplitude diagnostic population where noise, weak candidates, and threshold-edge behavior can dominate. This cut is not claiming those pulses are unphysical; it creates a cleaner presentation sample for morphology comparison.

## Why 18 mV

`18 mV` is used only to define pulse start/end after local baseline subtraction. It is a boundary/feature-extraction threshold, not the final event-quality threshold.

## Why Saturated Pulses Are Excluded

Pulses with `peak_mV >= {MAX_PEAK_MV:g} mV` are excluded because saturation or near-saturation can distort peak, integral, and width. Including them would bias the real-vs-simulation morphology comparison.

## Final Comparison Result

Peak matching controls the amplitude distribution directly. The matched peak KS statistic is `{summary_row["ks_peak_statistic"]:.6g}` when SciPy is available. The integral KS statistic is `{summary_row["ks_integral_statistic"]:.6g}` and the width KS statistic is `{summary_row["ks_width_statistic"]:.6g}`.

Median real/sim integral: `{summary_row["median_integral_real_mVns"]:.6g}` vs `{summary_row["median_integral_sim_mVns"]:.6g}` mV ns.

Median real/sim width: `{summary_row["median_width_real_ns"]:.6g}` vs `{summary_row["median_width_sim_ns"]:.6g}` ns.

## Remaining Discrepancy

After controlling for peak, differences in integral and width remain the key diagnostic. This points to missing temporal response effects in the current model, especially analog/electronic shaping, optical/electronic time dispersion, baseline behavior, trigger/acquisition effects, or a more realistic readout response.

## Recommended Next Improvement

Add an analog/electronic shaping and baseline model before retuning the optical/effective parameters. The fixed methodology parameters remain `voltage_scale_mV_per_pe = {VOLTAGE_SCALE_MV_PER_PE}` and `pde = {PDE}`.
"""

summary_path = OUTPUT_TABLES / f"{PREFIX}_analysis_summary.md"
summary_path.write_text(summary_md, encoding="utf-8")
display(Markdown(summary_md))
print("Wrote:", summary_path)
print("Output tables:", OUTPUT_TABLES)
print("Output figures:", OUTPUT_FIGURES)
# Out:
# # Latest HDF5 Panel A Final Analysis Summary
#
# ## Inputs
#
# - Real feature table: `latest_h5_panel_A_thresholded_pulse_features_all.csv`
# - Latest Panel A HDF5 file: `03A_040526_1h50m_AMP5_C5_thr0_82.h5`
# - CORSIKA table: `DATA_PROCESADA_ANTONIO_ROMERO.csv`
#
# ## Selection Criteria
#
# - Pulse boundary threshold: `18 mV` after local baseline subtraction.
# - Minimum peak: `50 mV`.
# - Saturation exclusion: `peak_mV < 900 mV`.
# - Minimum samples above threshold: `3`.
# - Width range: `16` to `600 ns`.
# - Positive integral required.
# - SNR is not used as a final hard cut; `snr_peak` and `baseline_rms_mV` are diagnostics.
#
# ## Pulse Counts
#
# - All candidate windows: `426568`.
# - Valid threshold pulses: `170329`.
# - Low-amplitude valid pulses below `50 mV`: `155793`. These remain a diagnostic population and are excluded only from the final cleaned comparison.
# - Saturated or near-saturated valid pulses at/above `900 mV`: `17`.
# - Requested matched-pair target: `20000`.
# - Final clean real sample available: `14505`.
# - Simulated pool generated: `100000`.
# - Simulated valid candidates after agreed filters: `9886`.
# - Final matched pairs used: `9886`.
# - Matching uses `min(N_MATCH_TARGET, len(real_clean), len(sim_valid))`, so the smaller valid sample sets the final number of pairs.
#
# ## Why 50 mV
#
# `50 mV` is used as a preliminary minimum peak cut because notebook 06 identified the region below this scale as a low-amplitude diagnostic population where noise, weak candidates, and threshold-edge behavior can dominate. This cut is not claiming those pulses are unphysical; it creates a cleaner presentation sample for morphology comparison.
#
# ## Why 18 mV
#
# `18 mV` is used only to define pulse start/end after local baseline subtraction. It is a boundary/feature-extraction threshold, not the final event-quality threshold.
#
# ## Why Saturated Pulses Are Excluded
#
# Pulses with `peak_mV >= 900 mV` are excluded because saturation or near-saturation can distort peak, integral, and width. Including them would bias the real-vs-simulation morphology comparison.
#
# ## Final Comparison Result
#
# Peak matching controls the amplitude distribution directly. The matched peak KS statistic is `0.680154` when SciPy is available. The integral KS statistic is `0.655675` and the width KS statistic is `0.629779`.
#
# Median real/sim integral: `8054.68` vs `2414.55` mV ns.
#
# Median real/sim width: `184` vs `88` ns.
#
# ## Remaining Discrepancy
#
# After controlling for peak, differences in integral and width remain the key diagnostic. This points to missing temporal response effects in the current model, especially analog/electronic shaping, optical/electronic time dispersion, baseline behavior, trigger/acquisition effects, or a more realistic readout response.
#
# ## Recommended Next Improvement
#
# Add an analog/electronic shaping and baseline model before retuning the optical/effective parameters. The fixed methodology parameters remain `voltage_scale_mV_per_pe = 0.12` and `pde = 0.41`.
# Wrote: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\tables\latest_h5_panel_A_final_digitized_analysis_summary.md
# Output tables: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\tables
# Output figures: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\figures

# %% [markdown]
# ## 12. Explicit digitization layer and ADC diagnostics
#
# Real HDF5 pulses are already measured/digitized signals from the DAQ. The simulated pulses are generated from a detector model, so this section explicitly places them into the same readout representation before the final comparison.
#
# The digitization layer tests the effect of 8 ns sampling and 14-bit ADC quantization over +/-1 V. If discrepancies remain after this step, they are likely due to analog pulse shape, electronics/shaping, baseline behavior, optical time dispersion, or missing detector-response effects rather than simple ADC quantization.

# %%
SAMPLING_INTERVAL_NS = 8.0
ADC_BITS = 14
ADC_VMIN_MV = -1000.0
ADC_VMAX_MV = 1000.0
ADC_LSB_MV = (ADC_VMAX_MV - ADC_VMIN_MV) / (2**ADC_BITS - 1)

digitized_config = copy.deepcopy(matched_config)
digitized_config["readout"]["sampling_interval_ns"] = SAMPLING_INTERVAL_NS
digitized_config["readout"]["adc_bits"] = ADC_BITS
digitized_config["readout"]["v_min_mV"] = ADC_VMIN_MV
digitized_config["readout"]["v_max_mV"] = ADC_VMAX_MV

print("Sampling interval [ns]:", SAMPLING_INTERVAL_NS)
print("ADC bits:", ADC_BITS)
print("ADC range [mV]:", ADC_VMIN_MV, ADC_VMAX_MV)
print("ADC LSB [mV]:", ADC_LSB_MV)
# Out:
# Sampling interval [ns]: 8.0
# ADC bits: 14
# ADC range [mV]: -1000.0 1000.0
# ADC LSB [mV]: 0.12207776353537203

# %%
def adc_digitize_from_analog(time_ns, analog_voltage_mV):
    time_ns = np.asarray(time_ns, dtype=float)
    analog_voltage_mV = np.asarray(analog_voltage_mV, dtype=float)
    sampled_time_ns = np.arange(time_ns[0], time_ns[-1] + 0.5 * SAMPLING_INTERVAL_NS, SAMPLING_INTERVAL_NS)
    sampled_voltage_mV = np.interp(sampled_time_ns, time_ns, analog_voltage_mV)
    clipped_mV = np.clip(sampled_voltage_mV, ADC_VMIN_MV, ADC_VMAX_MV)
    adc_code = np.rint((clipped_mV - ADC_VMIN_MV) / ADC_LSB_MV)
    adc_code = np.clip(adc_code, 0, 2**ADC_BITS - 1).astype(np.int64)
    digitized_voltage_mV = adc_code * ADC_LSB_MV + ADC_VMIN_MV
    clipped_mask = (sampled_voltage_mV < ADC_VMIN_MV) | (sampled_voltage_mV > ADC_VMAX_MV)
    return sampled_time_ns, sampled_voltage_mV, adc_code, digitized_voltage_mV, clipped_mask

def threshold_interval_around_peak(voltage_mV, threshold_mV=18.0):
    voltage_mV = np.asarray(voltage_mV, dtype=float)
    if len(voltage_mV) == 0 or not np.isfinite(voltage_mV).any():
        return None
    peak_index = int(np.nanargmax(voltage_mV))
    if not np.isfinite(voltage_mV[peak_index]) or voltage_mV[peak_index] < threshold_mV:
        return None
    left = peak_index
    while left > 0 and voltage_mV[left - 1] >= threshold_mV:
        left -= 1
    right = peak_index
    while right < len(voltage_mV) - 1 and voltage_mV[right + 1] >= threshold_mV:
        right += 1
    return left, right, peak_index

def digitized_feature_row(event_id, sampled_time_ns, sampled_voltage_mV, adc_code, digitized_voltage_mV, clipped_mask):
    interval = threshold_interval_around_peak(digitized_voltage_mV, THRESHOLD_MV)
    peak_mV = float(np.nanmax(digitized_voltage_mV)) if len(digitized_voltage_mV) else np.nan
    clipped_sample_count = int(np.sum(clipped_mask))
    clipped_fraction = clipped_sample_count / len(clipped_mask) if len(clipped_mask) else np.nan
    row = {
        "event_id": event_id,
        "digitized_peak_mV": peak_mV,
        "digitized_integral_mVns": np.nan,
        "digitized_rms_mV": np.nan,
        "digitized_width_ns": np.nan,
        "n_samples_above_threshold": int(np.sum(digitized_voltage_mV >= THRESHOLD_MV)),
        "clipped_sample_count": clipped_sample_count,
        "clipped_fraction": clipped_fraction,
        "valid_digitized_pulse": False,
    }
    if interval is None:
        return row
    left, right, peak_index = interval
    t = sampled_time_ns[left : right + 1]
    v = digitized_voltage_mV[left : right + 1]
    if len(t) < 2:
        return row
    row.update({
        "digitized_integral_mVns": float(np.trapezoid(v, t)),
        "digitized_rms_mV": float(np.sqrt(np.mean(v**2))),
        "digitized_width_ns": float(t[-1] - t[0]),
        "threshold_start_time_ns": float(sampled_time_ns[left]),
        "threshold_end_time_ns": float(sampled_time_ns[right]),
        "digitized_peak_time_ns": float(sampled_time_ns[peak_index]),
        "valid_digitized_pulse": bool(np.trapezoid(v, t) > 0),
    })
    return row

# %% [markdown]
# ### 12.1 Regenerate matched simulated waveforms and digitized features
#
# The matched rows store `generated_photons` and `simulation_seed`, so each simulated pulse is regenerated deterministically without changing the matching logic.

# %%
sim_digitized_feature_rows = []
representative_sim_waveforms = []
representative_positions = np.linspace(0, len(matched_sim) - 1, min(N_OVERLAY_WAVEFORMS, len(matched_sim))).round().astype(int)
representative_position_set = set(int(pos) for pos in representative_positions)
median_peak_index = int((matched_sim["match_peak_mV"] - matched_sim["match_peak_mV"].median()).abs().idxmin())
single_pulse_demo = None

for local_position, (_, row) in enumerate(matched_sim.iterrows()):
    rng = np.random.default_rng(int(row["simulation_seed"]))
    result = simulate_detector_event_from_config(
        generated_photons=int(row["generated_photons"]),
        config=digitized_config,
        rng=rng,
    )
    analog_time_ns = result.sipm_response.time_ns
    analog_voltage_mV = result.analog_voltage_mV
    sampled_time_ns, sampled_voltage_mV, adc_code, digitized_voltage_mV, clipped_mask = adc_digitize_from_analog(
        analog_time_ns,
        analog_voltage_mV,
    )
    feature_row = digitized_feature_row(
        event_id=str(row["event_id"]),
        sampled_time_ns=sampled_time_ns,
        sampled_voltage_mV=sampled_voltage_mV,
        adc_code=adc_code,
        digitized_voltage_mV=digitized_voltage_mV,
        clipped_mask=clipped_mask,
    )
    feature_row.update({
        "match_id": int(row["match_id"]),
        "matched_real_event_id": str(row["matched_real_event_id"]),
        "generated_photons": int(row["generated_photons"]),
        "simulation_seed": int(row["simulation_seed"]),
        "match_peak_mV": float(row["match_peak_mV"]),
    })
    sim_digitized_feature_rows.append(feature_row)

    if local_position in representative_position_set:
        representative_sim_waveforms.append({
            "event_id": str(row["event_id"]),
            "analog_time_ns": analog_time_ns,
            "analog_voltage_mV": analog_voltage_mV,
            "sampled_time_ns": sampled_time_ns,
            "sampled_voltage_mV": sampled_voltage_mV,
            "adc_code": adc_code,
            "digitized_voltage_mV": digitized_voltage_mV,
        })
    if local_position == median_peak_index:
        single_pulse_demo = {
            "event_id": str(row["event_id"]),
            "analog_time_ns": analog_time_ns,
            "analog_voltage_mV": analog_voltage_mV,
            "sampled_time_ns": sampled_time_ns,
            "sampled_voltage_mV": sampled_voltage_mV,
            "adc_code": adc_code,
            "digitized_voltage_mV": digitized_voltage_mV,
        }

sim_digitized_features = pd.DataFrame(sim_digitized_feature_rows)
matched_sim_digitized = matched_sim.merge(sim_digitized_features, on=["event_id", "match_id"], how="left", suffixes=("", "_digitized"))
matched_real_digitized = matched_real.copy()

sim_digitized_features.to_csv(OUTPUT_TABLES / f"{PREFIX}_simulated_features.csv", index=False)
matched_real_digitized.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_real.csv", index=False)
matched_sim_digitized.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_simulated.csv", index=False)

print("Digitized simulated feature rows:", len(sim_digitized_features))
print("Valid digitized simulated pulses:", int(sim_digitized_features["valid_digitized_pulse"].sum()))
print("Representative simulated waveforms kept:", len(representative_sim_waveforms))
display(sim_digitized_features.describe(include="all"))
# Out:
# Digitized simulated feature rows: 9886
# Valid digitized simulated pulses: 9886
# Representative simulated waveforms kept: 250
#                event_id  digitized_peak_mV  digitized_integral_mVns  \
# count              9886        9886.000000              9886.000000
# unique             9886                NaN                      NaN
# top     sim_pool_077799                NaN                      NaN
# freq                  1                NaN                      NaN
# mean                NaN         121.434503             28896.982754
# std                 NaN         159.516311             48407.846119
# min                 NaN          30.336324              3745.834096
# 25%                 NaN          43.520723              7400.598181
# 50%                 NaN          65.250565             13073.551853
# 75%                 NaN         121.040103             27717.389977
# max                 NaN        1000.000000            415386.193005
#
#         digitized_rms_mV  digitized_width_ns  n_samples_above_threshold  \
# count        9886.000000         9886.000000                9886.000000
# unique               NaN                 NaN                        NaN
# top                  NaN                 NaN                        NaN
# freq                 NaN                 NaN                        NaN
# mean           65.647312          377.506777                  48.188347
# std            69.532034          174.114130                  21.764266
# min            24.643552          152.000000                  20.000000
# 25%            31.506499          240.000000                  31.000000
# 50%            42.091515          328.000000                  42.000000
# 75%            67.318257          464.000000                  59.000000
# max           561.243410          992.000000                 125.000000
#
#         clipped_sample_count  clipped_fraction valid_digitized_pulse  \
# count            9886.000000       9886.000000                  9886
# unique                   NaN               NaN                     1
# top                      NaN               NaN                  True
# freq                     NaN               NaN                  9886
# mean                0.183694          0.001458                   NaN
# std                 1.773360          0.014074                   NaN
# min                 0.000000          0.000000                   NaN
# 25%                 0.000000          0.000000                   NaN
# 50%                 0.000000          0.000000                   NaN
# 75%                 0.000000          0.000000                   NaN
# max                25.000000          0.198413                   NaN
#
#         threshold_start_time_ns  threshold_end_time_ns  \
# count               9886.000000            9886.000000
# unique                      NaN                    NaN
# top                         NaN                    NaN
# freq                        NaN                    NaN
# mean                   8.727493             386.234271
# std                    2.308697             173.349461
# min                    8.000000             168.000000
# 25%                    8.000000             248.000000
# 50%                    8.000000             336.000000
# 75%                    8.000000             472.000000
# max                   24.000000            1000.000000
#
#         digitized_peak_time_ns     match_id         matched_real_event_id  \
# count              9886.000000  9886.000000                          9886
# unique                     NaN          NaN                          9886
# top                        NaN          NaN  threshold_candidate_A_078245
# freq                       NaN          NaN                             1
# mean                 47.898847  4942.500000                           NaN
# std                   3.759848  2853.986715                           NaN
# min                  16.000000     0.000000                           NaN
# 25%                  48.000000  2471.250000                           NaN
# 50%                  48.000000  4942.500000                           NaN
# 75%                  48.000000  7413.750000                           NaN
# max                  56.000000  9885.000000                           NaN
#
#         generated_photons  simulation_seed  match_peak_mV
# count        9.886000e+03     9.886000e+03    9886.000000
# unique                NaN              NaN            NaN
# top                   NaN              NaN            NaN
# freq                  NaN              NaN            NaN
# mean         1.314518e+05     4.205017e+07      59.196705
# std          3.062571e+05     2.887120e+04      70.463056
# min          2.003600e+04     4.200000e+07      18.066406
# 25%          3.795500e+04     4.202503e+07      22.338867
# 50%          5.814650e+04     4.205026e+07      33.203125
# 75%          1.089210e+05     4.207530e+07      61.767578
# max          5.295967e+06     4.210000e+07     522.094727

# %% [markdown]
# ### 12.2 Real measured HDF5 waveforms for overlay
#
# These are already DAQ-measured signals. They are plotted baseline-corrected and aligned to `threshold_start_time_ns` when available.

# %%
if "samples_A" not in globals():
    print("Loading HDF5 samples for real waveform overlays...")
    samples_A = load_test_panel_h5_samples(DATA_H5_PANEL_A, voltage_unit="auto")

representative_real_rows = matched_real_digitized.sample(
    n=min(N_OVERLAY_WAVEFORMS, len(matched_real_digitized)),
    random_state=RANDOM_SEED,
).copy()

def real_measured_waveform_from_row(row, samples):
    start = int(row["row_start"])
    end = int(row["row_end"])
    candidate = samples.iloc[start : end + 1]
    t = candidate["time_ns"].to_numpy(dtype=float)
    v = candidate["voltage_mV"].to_numpy(dtype=float) - float(row["baseline_mV"])
    if "threshold_start_time_ns" in row and np.isfinite(row["threshold_start_time_ns"]):
        t0 = float(row["threshold_start_time_ns"])
    else:
        interval = threshold_interval_around_peak(v, THRESHOLD_MV)
        t0 = t[int(interval[0])] if interval is not None else t[0]
    return t - t0, v

representative_real_waveforms = [
    real_measured_waveform_from_row(row, samples_A)
    for _, row in representative_real_rows.iterrows()
]
print("Representative real measured waveforms:", len(representative_real_waveforms))
# Out:
# Representative real measured waveforms: 250

# %% [markdown]
# ### 12.3 ADC demonstration and waveform overlays

# %%
fig, ax = plt.subplots(figsize=(8, 4.5))
ax.plot(single_pulse_demo["analog_time_ns"], single_pulse_demo["analog_voltage_mV"], label="Analog SiPM response", linewidth=1.6)
ax.scatter(single_pulse_demo["sampled_time_ns"], single_pulse_demo["sampled_voltage_mV"], label="8 ns sampled points", s=18, alpha=0.8)
ax.step(single_pulse_demo["sampled_time_ns"], single_pulse_demo["digitized_voltage_mV"], where="mid", label="ADC reconstructed digitized", linewidth=1.4)
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Voltage [mV]")
ax.set_title("Single-pulse ADC demonstration")
ax.grid(alpha=0.25)
ax.legend()
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_single_pulse_adc_demo.png")
plt.show()

fig, ax = plt.subplots(figsize=(7.4, 4.4))
for wf in representative_sim_waveforms:
    ax.plot(wf["analog_time_ns"], wf["analog_voltage_mV"], color="tab:orange", alpha=0.04, linewidth=1.0)
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Analog voltage [mV]")
ax.set_title("Overlay of matched simulated analog pulses")
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_sim_analog.png")
plt.show()

fig, ax = plt.subplots(figsize=(7.4, 4.4))
for wf in representative_sim_waveforms:
    ax.step(wf["sampled_time_ns"], wf["digitized_voltage_mV"], where="mid", color="tab:green", alpha=0.04, linewidth=1.0)
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Digitized voltage [mV]")
ax.set_title("Overlay of matched simulated 8 ns ADC pulses")
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_sim_adc.png")
plt.show()

fig, ax = plt.subplots(figsize=(7.4, 4.4))
for t, v in representative_real_waveforms:
    ax.plot(t, v, color="tab:blue", alpha=0.04, linewidth=1.0)
ax.axhline(THRESHOLD_MV, color="tab:red", linestyle="--", linewidth=1.0)
ax.set_xlabel("Time from threshold start [ns]")
ax.set_ylabel("Baseline-corrected measured voltage [mV]")
ax.set_title("Overlay of measured HDF5 Panel A pulses")
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_real_hdf5.png")
plt.show()

fig, ax = plt.subplots(figsize=(7.4, 4.4))
for t, v in representative_real_waveforms:
    ax.plot(t, v, color="tab:blue", alpha=0.035, linewidth=1.0)
for wf in representative_sim_waveforms:
    t = wf["sampled_time_ns"] - wf["sampled_time_ns"][0]
    ax.step(t, wf["digitized_voltage_mV"], where="mid", color="tab:green", alpha=0.035, linewidth=1.0)
ax.axhline(THRESHOLD_MV, color="tab:red", linestyle="--", linewidth=1.0)
ax.set_xlabel("Aligned time [ns]")
ax.set_ylabel("Voltage [mV]")
ax.set_title("Measured HDF5 pulses vs digitized simulated pulses")
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_overlay_real_vs_sim_adc.png")
plt.show()

# %% [markdown]
# ### 12.4 Point-wise voltage distribution

# %%
real_pointwise_voltage = np.concatenate([v for _, v in representative_real_waveforms])
sim_pointwise_voltage = np.concatenate([wf["digitized_voltage_mV"] for wf in representative_sim_waveforms])
bins = common_linear_bins(real_pointwise_voltage, sim_pointwise_voltage, n_bins=80)

fig, ax = plt.subplots(figsize=(7.2, 4.2))
ax.hist(real_pointwise_voltage, bins=bins, density=True, histtype="step", linewidth=2.0, label="Measured HDF5")
ax.hist(sim_pointwise_voltage, bins=bins, density=True, histtype="step", linewidth=2.0, label="Digitized simulation")
ax.set_xlabel("Point-wise voltage [mV]")
ax.set_ylabel("Normalized density")
ax.set_title("Point-wise voltage distribution")
ax.legend()
ax.grid(alpha=0.25)
save_figure(fig, OUTPUT_FIGURES / f"{PREFIX}_pointwise_voltage_distribution.png")
plt.show()

# %% [markdown]
# ### 12.5 Post-digitization feature comparison
#
# The real columns are the thresholded measured features from the HDF5 table. The simulated columns are recomputed from the explicit 8 ns ADC waveforms.

# %%
digitized_compare = matched_real_digitized[[
    "match_id", "event_id", "match_peak_mV", "integral_mVns", "width_ns", "rms_mV"
]].merge(
    matched_sim_digitized[[
        "match_id", "event_id", "digitized_peak_mV", "digitized_integral_mVns",
        "digitized_width_ns", "digitized_rms_mV", "clipped_sample_count",
        "clipped_fraction", "valid_digitized_pulse",
    ]],
    on="match_id",
    suffixes=("_real", "_sim"),
)

valid_digitized_compare = digitized_compare[digitized_compare["valid_digitized_pulse"] == True].copy()

def ks_stat(real_values, sim_values):
    if ks_2samp is None:
        return np.nan, np.nan
    real_values = np.asarray(real_values, dtype=float)
    sim_values = np.asarray(sim_values, dtype=float)
    real_values = real_values[np.isfinite(real_values)]
    sim_values = sim_values[np.isfinite(sim_values)]
    if len(real_values) == 0 or len(sim_values) == 0:
        return np.nan, np.nan
    result = ks_2samp(real_values, sim_values)
    return float(result.statistic), float(result.pvalue)

ks_peak, ks_peak_p = ks_stat(valid_digitized_compare["match_peak_mV"], valid_digitized_compare["digitized_peak_mV"])
ks_integral, ks_integral_p = ks_stat(valid_digitized_compare["integral_mVns"], valid_digitized_compare["digitized_integral_mVns"])
ks_width, ks_width_p = ks_stat(valid_digitized_compare["width_ns"], valid_digitized_compare["digitized_width_ns"])
ks_rms, ks_rms_p = ks_stat(valid_digitized_compare["rms_mV"], valid_digitized_compare["digitized_rms_mV"])

clipped_pulses = int((sim_digitized_features["clipped_sample_count"] > 0).sum())
clipped_fraction_pulses = clipped_pulses / len(sim_digitized_features) if len(sim_digitized_features) else np.nan

digitized_summary = pd.DataFrame([{
    "n_real_clean": len(real_clean),
    "n_real_used": len(matched_real_digitized),
    "n_simulated_pool": len(sim_pool_features),
    "n_simulated_valid": len(sim_valid),
    "n_matched": len(matched_real_digitized),
    "adc_bits": ADC_BITS,
    "adc_vmin_mV": ADC_VMIN_MV,
    "adc_vmax_mV": ADC_VMAX_MV,
    "adc_lsb_mV": ADC_LSB_MV,
    "sampling_interval_ns": SAMPLING_INTERVAL_NS,
    "n_clipped_simulated_pulses": clipped_pulses,
    "fraction_clipped_simulated_pulses": clipped_fraction_pulses,
    "mean_real_peak_mV": valid_digitized_compare["match_peak_mV"].mean(),
    "median_real_peak_mV": valid_digitized_compare["match_peak_mV"].median(),
    "mean_digitized_sim_peak_mV": valid_digitized_compare["digitized_peak_mV"].mean(),
    "median_digitized_sim_peak_mV": valid_digitized_compare["digitized_peak_mV"].median(),
    "mean_real_integral_mVns": valid_digitized_compare["integral_mVns"].mean(),
    "median_real_integral_mVns": valid_digitized_compare["integral_mVns"].median(),
    "mean_digitized_sim_integral_mVns": valid_digitized_compare["digitized_integral_mVns"].mean(),
    "median_digitized_sim_integral_mVns": valid_digitized_compare["digitized_integral_mVns"].median(),
    "mean_real_width_ns": valid_digitized_compare["width_ns"].mean(),
    "median_real_width_ns": valid_digitized_compare["width_ns"].median(),
    "mean_digitized_sim_width_ns": valid_digitized_compare["digitized_width_ns"].mean(),
    "median_digitized_sim_width_ns": valid_digitized_compare["digitized_width_ns"].median(),
    "mean_real_rms_mV": valid_digitized_compare["rms_mV"].mean(),
    "median_real_rms_mV": valid_digitized_compare["rms_mV"].median(),
    "mean_digitized_sim_rms_mV": valid_digitized_compare["digitized_rms_mV"].mean(),
    "median_digitized_sim_rms_mV": valid_digitized_compare["digitized_rms_mV"].median(),
    "ks_peak_statistic": ks_peak,
    "ks_peak_pvalue": ks_peak_p,
    "ks_integral_statistic": ks_integral,
    "ks_integral_pvalue": ks_integral_p,
    "ks_width_statistic": ks_width,
    "ks_width_pvalue": ks_width_p,
    "ks_rms_statistic": ks_rms,
    "ks_rms_pvalue": ks_rms_p,
}])

sim_digitized_features.to_csv(OUTPUT_TABLES / f"{PREFIX}_simulated_features.csv", index=False)
digitized_summary.to_csv(OUTPUT_TABLES / f"{PREFIX}_comparison_summary.csv", index=False)
matched_real_digitized.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_real.csv", index=False)
matched_sim_digitized.to_csv(OUTPUT_TABLES / f"{PREFIX}_matched_simulated.csv", index=False)

display(digitized_summary.T)
# Out:
#                                                 0
# n_real_clean                         1.450500e+04
# n_real_used                          9.886000e+03
# n_simulated_pool                     1.000000e+05
# n_simulated_valid                    9.886000e+03
# n_matched                            9.886000e+03
# adc_bits                             1.400000e+01
# adc_vmin_mV                         -1.000000e+03
# adc_vmax_mV                          1.000000e+03
# adc_lsb_mV                           1.220778e-01
# sampling_interval_ns                 8.000000e+00
# n_clipped_simulated_pulses           1.300000e+02
# fraction_clipped_simulated_pulses    1.314991e-02
# mean_real_peak_mV                    8.184516e+01
# median_real_peak_mV                  6.551400e+01
# mean_digitized_sim_peak_mV           1.214345e+02
# median_digitized_sim_peak_mV         6.525056e+01
# mean_real_integral_mVns              1.056047e+04
# median_real_integral_mVns            8.054684e+03
# mean_digitized_sim_integral_mVns     2.889698e+04
# median_digitized_sim_integral_mVns   1.307355e+04
# mean_real_width_ns                   1.923294e+02
# median_real_width_ns                 1.840000e+02
# mean_digitized_sim_width_ns          3.775068e+02
# median_digitized_sim_width_ns        3.280000e+02
# mean_real_rms_mV                     5.463628e+01
# median_real_rms_mV                   4.545455e+01
# mean_digitized_sim_rms_mV            6.564731e+01
# median_digitized_sim_rms_mV          4.209151e+01
# ks_peak_statistic                    3.585879e-01
# ks_peak_pvalue                       0.000000e+00
# ks_integral_statistic                3.190370e-01
# ks_integral_pvalue                  9.881313e-324
# ks_width_statistic                   6.100546e-01
# ks_width_pvalue                      0.000000e+00
# ks_rms_statistic                     3.726482e-01
# ks_rms_pvalue                        0.000000e+00

# %% [markdown]
# ### 12.6 Normalized digitized feature plots

# %%
def normalized_digitized_hist(real_col, sim_col, xlabel, output_name, width_bins=False):
    real_values = pd.to_numeric(valid_digitized_compare[real_col], errors="coerce")
    sim_values = pd.to_numeric(valid_digitized_compare[sim_col], errors="coerce")
    mask = np.isfinite(real_values) & np.isfinite(sim_values)
    real_values = real_values[mask].to_numpy(dtype=float)
    sim_values = sim_values[mask].to_numpy(dtype=float)
    bins = temporal_bins_8ns(real_values, sim_values) if width_bins else common_linear_bins(real_values, sim_values, n_bins=60)
    fig, ax = plt.subplots(figsize=(7.2, 4.2))
    ax.hist(real_values, bins=bins, density=True, histtype="step", linewidth=2.0, label="Measured HDF5")
    ax.hist(sim_values, bins=bins, density=True, histtype="step", linewidth=2.0, label="Digitized simulation")
    ax.set_xlabel(xlabel)
    ax.set_ylabel("Normalized density")
    ax.set_title(f"Measured HDF5 vs digitized simulation: {xlabel}")
    ax.legend()
    ax.grid(alpha=0.25)
    save_figure(fig, OUTPUT_FIGURES / output_name)
    plt.show()

normalized_digitized_hist("match_peak_mV", "digitized_peak_mV", "Peak [mV]", f"{PREFIX}_hist_peak.png")
normalized_digitized_hist("integral_mVns", "digitized_integral_mVns", "Integral [mV ns]", f"{PREFIX}_hist_integral.png")
normalized_digitized_hist("width_ns", "digitized_width_ns", "Width [ns]", f"{PREFIX}_hist_width.png", width_bins=True)
normalized_digitized_hist("rms_mV", "digitized_rms_mV", "RMS [mV]", f"{PREFIX}_hist_rms.png")

# %% [markdown]
# ### 12.7 Normalized 2D digitized comparisons

# %%
real_for_2d = valid_digitized_compare.rename(columns={
    "match_peak_mV": "peak_for_plot_mV",
    "integral_mVns": "integral_for_plot_mVns",
    "width_ns": "width_for_plot_ns",
})
sim_for_2d = valid_digitized_compare.rename(columns={
    "digitized_peak_mV": "peak_for_plot_mV",
    "digitized_integral_mVns": "integral_for_plot_mVns",
    "digitized_width_ns": "width_for_plot_ns",
})

peak_bins_digitized = common_linear_bins(real_for_2d["peak_for_plot_mV"], sim_for_2d["peak_for_plot_mV"], n_bins=50)
integral_bins_digitized = common_linear_bins(real_for_2d["integral_for_plot_mVns"], sim_for_2d["integral_for_plot_mVns"], n_bins=50)
width_bins_digitized = temporal_bins_8ns(real_for_2d["width_for_plot_ns"], sim_for_2d["width_for_plot_ns"])

side_by_side_hist2d(
    real_for_2d,
    sim_for_2d,
    "peak_for_plot_mV",
    "integral_for_plot_mVns",
    peak_bins_digitized,
    integral_bins_digitized,
    "Peak [mV]",
    "Integral [mV ns]",
    f"{PREFIX}_2d_integral_vs_peak.png",
)

side_by_side_hist2d(
    real_for_2d,
    sim_for_2d,
    "width_for_plot_ns",
    "integral_for_plot_mVns",
    width_bins_digitized,
    integral_bins_digitized,
    "Width [ns]",
    "Integral [mV ns]",
    f"{PREFIX}_2d_integral_vs_width.png",
)

side_by_side_hist2d(
    real_for_2d,
    sim_for_2d,
    "peak_for_plot_mV",
    "integral_for_plot_mVns",
    percentile_bins(real_for_2d, sim_for_2d, "peak_for_plot_mV", n_bins=50),
    percentile_bins(real_for_2d, sim_for_2d, "integral_for_plot_mVns", n_bins=50),
    "Peak [mV]",
    "Integral [mV ns]",
    f"{PREFIX}_2d_integral_vs_peak_p5_p95.png",
    subtitle=" p5-p95",
)

side_by_side_hist2d(
    real_for_2d,
    sim_for_2d,
    "width_for_plot_ns",
    "integral_for_plot_mVns",
    percentile_bins(real_for_2d, sim_for_2d, "width_for_plot_ns", temporal=True),
    percentile_bins(real_for_2d, sim_for_2d, "integral_for_plot_mVns", n_bins=50),
    "Width [ns]",
    "Integral [mV ns]",
    f"{PREFIX}_2d_integral_vs_width_p5_p95.png",
    subtitle=" p5-p95",
)

# %% [markdown]
# ### 12.8 Final digitized analysis summary

# %%
digitized_summary_row = digitized_summary.iloc[0].to_dict()
digitized_summary_md = f"""# Latest HDF5 Panel A Final Digitized Analysis Summary

## Provenance

- Input notebook copied from: `notebooks/07_latest_h5_final_thresholded_real_vs_sim_matching.ipynb`
- HDF5 file used: `{DATA_H5_PANEL_A.name}`
- Output prefix: `{PREFIX}_`

## Real-Pulse Selection Criteria

- `THRESHOLD_MV = {THRESHOLD_MV:g}` mV for pulse start/end after local baseline subtraction.
- `MIN_PEAK_MV = {MIN_PEAK_MV:g}` mV.
- `MAX_PEAK_MV = {MAX_PEAK_MV:g}` mV.
- `MIN_SAMPLES_ABOVE_THRESHOLD = {MIN_SAMPLES_ABOVE_THRESHOLD}`.
- Width range: `{MIN_WIDTH_NS:g}` to `{MAX_WIDTH_NS:g}` ns.
- SNR is not used as a hard cut; it remains diagnostic only.

## Counts

- Real clean pulses retained: `{len(real_clean)}`.
- Matched events used: `{len(matched_real_digitized)}`.
- Simulated pool: `{len(sim_pool_features)}`.
- Simulated valid candidates before matching: `{len(sim_valid)}`.
- Valid digitized simulated pulses: `{int(sim_digitized_features["valid_digitized_pulse"].sum())}`.

## Digitization Parameters

- Sampling interval: `{SAMPLING_INTERVAL_NS:g}` ns.
- ADC bits: `{ADC_BITS}`.
- ADC range: `{ADC_VMIN_MV:g}` to `{ADC_VMAX_MV:g}` mV.
- ADC LSB: `{ADC_LSB_MV:.6g}` mV.
- Clipped simulated pulses: `{clipped_pulses}`.
- Fraction clipped simulated pulses: `{clipped_fraction_pulses:.6g}`.

## Main Comparison After Digitization

- Median real/digitized-sim peak: `{digitized_summary_row["median_real_peak_mV"]:.6g}` vs `{digitized_summary_row["median_digitized_sim_peak_mV"]:.6g}` mV.
- Median real/digitized-sim integral: `{digitized_summary_row["median_real_integral_mVns"]:.6g}` vs `{digitized_summary_row["median_digitized_sim_integral_mVns"]:.6g}` mV ns.
- Median real/digitized-sim width: `{digitized_summary_row["median_real_width_ns"]:.6g}` vs `{digitized_summary_row["median_digitized_sim_width_ns"]:.6g}` ns.
- Median real/digitized-sim RMS: `{digitized_summary_row["median_real_rms_mV"]:.6g}` vs `{digitized_summary_row["median_digitized_sim_rms_mV"]:.6g}` mV.

KS statistics when SciPy is available:

- Peak: `{digitized_summary_row["ks_peak_statistic"]:.6g}`.
- Integral: `{digitized_summary_row["ks_integral_statistic"]:.6g}`.
- Width: `{digitized_summary_row["ks_width_statistic"]:.6g}`.
- RMS: `{digitized_summary_row["ks_rms_statistic"]:.6g}`.

## Final Interpretation

The ADC/readout layer creates a fairer comparison because the real HDF5 pulses are measured after acquisition, while the raw simulation is an analog SiPM response. The 14-bit ADC over +/-1 V has an LSB of approximately `{ADC_LSB_MV:.3f}` mV, which is small compared with the selected pulse amplitudes. Therefore, quantization is expected to have a minor effect on amplitude. If the matched digitized simulation still reproduces peak better than integral and width, then the dominant discrepancy is likely not ADC quantization, but the analog/electronic pulse-shape model.

## Remaining Discrepancy and Next Improvement

If differences remain in integral, width, or RMS after explicit 8 ns ADC digitization, the next recommended improvement is analog/electronic shaping, a baseline model, optical time dispersion, or an improved pulse-shape response before retuning fixed optical/electronic constants.
"""

digitized_summary_path = OUTPUT_TABLES / f"{PREFIX}_analysis_summary.md"
digitized_summary_path.write_text(digitized_summary_md, encoding="utf-8")
display(Markdown(digitized_summary_md))
print("Wrote:", digitized_summary_path)
# Out:
# # Latest HDF5 Panel A Final Digitized Analysis Summary
#
# ## Provenance
#
# - Input notebook copied from: `notebooks/07_latest_h5_final_thresholded_real_vs_sim_matching.ipynb`
# - HDF5 file used: `03A_040526_1h50m_AMP5_C5_thr0_82.h5`
# - Output prefix: `latest_h5_panel_A_final_digitized_`
#
# ## Real-Pulse Selection Criteria
#
# - `THRESHOLD_MV = 18` mV for pulse start/end after local baseline subtraction.
# - `MIN_PEAK_MV = 50` mV.
# - `MAX_PEAK_MV = 900` mV.
# - `MIN_SAMPLES_ABOVE_THRESHOLD = 3`.
# - Width range: `16` to `600` ns.
# - SNR is not used as a hard cut; it remains diagnostic only.
#
# ## Counts
#
# - Real clean pulses retained: `14505`.
# - Matched events used: `9886`.
# - Simulated pool: `100000`.
# - Simulated valid candidates before matching: `9886`.
# - Valid digitized simulated pulses: `9886`.
#
# ## Digitization Parameters
#
# - Sampling interval: `8` ns.
# - ADC bits: `14`.
# - ADC range: `-1000` to `1000` mV.
# - ADC LSB: `0.122078` mV.
# - Clipped simulated pulses: `130`.
# - Fraction clipped simulated pulses: `0.0131499`.
#
# ## Main Comparison After Digitization
#
# - Median real/digitized-sim peak: `65.514` vs `65.2506` mV.
# - Median real/digitized-sim integral: `8054.68` vs `13073.6` mV ns.
# - Median real/digitized-sim width: `184` vs `328` ns.
# - Median real/digitized-sim RMS: `45.4545` vs `42.0915` mV.
#
# KS statistics when SciPy is available:
#
# - Peak: `0.358588`.
# - Integral: `0.319037`.
# - Width: `0.610055`.
# - RMS: `0.372648`.
#
# ## Final Interpretation
#
# The ADC/readout layer creates a fairer comparison because the real HDF5 pulses are measured after acquisition, while the raw simulation is an analog SiPM response. The 14-bit ADC over +/-1 V has an LSB of approximately `0.122` mV, which is small compared with the selected pulse amplitudes. Therefore, quantization is expected to have a minor effect on amplitude. If the matched digitized simulation still reproduces peak better than integral and width, then the dominant discrepancy is likely not ADC quantization, but the analog/electronic pulse-shape model.
#
# ## Remaining Discrepancy and Next Improvement
#
# If differences remain in integral, width, or RMS after explicit 8 ns ADC digitization, the next recommended improvement is analog/electronic shaping, a baseline model, optical time dispersion, or an improved pulse-shape response before retuning fixed optical/electronic constants.
# Wrote: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\tables\latest_h5_panel_A_final_digitized_analysis_summary.md

# %%
# 12 pares aleatorios:
# 1) Real HDF5 re-digitalizado vs simulacion analogica
# 2) Real HDF5 re-digitalizado vs simulacion digitalizada ADC
#
# Nota: el real HDF5 ya viene digitalizado por la DAQ.
# Aqui lo pasamos por el mismo modelo ADC solo para representarlo de forma simetrica.

N_RANDOM_PAIRS = 12
PAIR_OVERLAY_SEED = 123

rng_pairs = np.random.default_rng(PAIR_OVERLAY_SEED)
available_match_ids = matched_real_digitized["match_id"].dropna().astype(int).unique()
selected_match_ids = rng_pairs.choice(
    available_match_ids,
    size=min(N_RANDOM_PAIRS, len(available_match_ids)),
    replace=False,
)

pair_waveforms = []

for match_id in selected_match_ids:
    real_row = matched_real_digitized.loc[
        matched_real_digitized["match_id"].astype(int) == int(match_id)
    ].iloc[0]

    sim_row = matched_sim_digitized.loc[
        matched_sim_digitized["match_id"].astype(int) == int(match_id)
    ].iloc[0]

    # Real HDF5 medido, baseline-corrected, iniciando en 0.
    start = int(real_row["row_start"])
    end = int(real_row["row_end"])
    candidate = samples_A.iloc[start : end + 1]

    real_t = candidate["time_ns"].to_numpy(dtype=float)
    real_v = candidate["voltage_mV"].to_numpy(dtype=float) - float(real_row["baseline_mV"])
    real_t = real_t - real_t[0]

    # Re-digitalizacion del real con el mismo ADC model.
    real_adc_t, real_sampled_v, real_adc_code, real_adc_v, real_clipped_mask = adc_digitize_from_analog(
        real_t,
        real_v,
    )
    real_adc_t = real_adc_t - real_adc_t[0]

    # Simulado regenerado deterministicamente.
    sim_rng = np.random.default_rng(int(sim_row["simulation_seed"]))
    sim_result = simulate_detector_event_from_config(
        generated_photons=int(sim_row["generated_photons"]),
        config=digitized_config,
        rng=sim_rng,
    )

    analog_t = sim_result.sipm_response.time_ns
    analog_v = sim_result.analog_voltage_mV
    analog_t = analog_t - analog_t[0]

    sim_adc_t, sim_sampled_v, sim_adc_code, sim_adc_v, sim_clipped_mask = adc_digitize_from_analog(
        sim_result.sipm_response.time_ns,
        sim_result.analog_voltage_mV,
    )
    sim_adc_t = sim_adc_t - sim_adc_t[0]

    pair_waveforms.append({
        "match_id": int(match_id),
        "real_peak_mV": float(real_row["match_peak_mV"]),
        "sim_peak_mV": float(sim_row["match_peak_mV"]),
        "real_adc_t": real_adc_t,
        "real_adc_v": real_adc_v,
        "analog_t": analog_t,
        "analog_v": analog_v,
        "sim_adc_t": sim_adc_t,
        "sim_adc_v": sim_adc_v,
    })


# Figura 1: real digitalizado vs sim analogica
fig, axes = plt.subplots(3, 4, figsize=(16, 10), sharex=False, sharey=False)
axes = axes.ravel()

for ax, wf in zip(axes, pair_waveforms):
    ax.step(
        wf["real_adc_t"],
        wf["real_adc_v"],
        where="mid",
        color="tab:blue",
        linewidth=1.7,
        alpha=0.9,
        label="Real HDF5 ADC",
    )
    ax.plot(
        wf["analog_t"],
        wf["analog_v"],
        color="tab:orange",
        linewidth=1.6,
        alpha=0.85,
        label="Sim analog",
    )
    ax.axhline(THRESHOLD_MV, color="tab:red", linestyle="--", linewidth=0.9, alpha=0.7)
    ax.set_title(
        f"match {wf['match_id']} | real {wf['real_peak_mV']:.1f} mV | sim {wf['sim_peak_mV']:.1f} mV",
        fontsize=9,
    )
    ax.set_xlabel("Time from waveform start [ns]")
    ax.set_ylabel("Voltage [mV]")
    ax.grid(alpha=0.2)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3)
fig.suptitle("12 random matched pairs: digitized real HDF5 vs simulated analog", y=1.02)
fig.tight_layout()

output_path_analog = OUTPUT_FIGURES / f"{PREFIX}_12_random_pairs_real_adc_vs_sim_analog_start0.png"
save_figure(fig, output_path_analog)
plt.show()


# Figura 2: real digitalizado vs sim digitalizada ADC
fig, axes = plt.subplots(3, 4, figsize=(16, 10), sharex=False, sharey=False)
axes = axes.ravel()

for ax, wf in zip(axes, pair_waveforms):
    ax.step(
        wf["real_adc_t"],
        wf["real_adc_v"],
        where="mid",
        color="tab:blue",
        linewidth=1.7,
        alpha=0.9,
        label="Real HDF5 ADC",
    )
    ax.step(
        wf["sim_adc_t"],
        wf["sim_adc_v"],
        where="mid",
        color="tab:green",
        linewidth=1.6,
        alpha=0.85,
        label="Sim ADC 8 ns",
    )
    ax.axhline(THRESHOLD_MV, color="tab:red", linestyle="--", linewidth=0.9, alpha=0.7)
    ax.set_title(
        f"match {wf['match_id']} | real {wf['real_peak_mV']:.1f} mV | sim {wf['sim_peak_mV']:.1f} mV",
        fontsize=9,
    )
    ax.set_xlabel("Time from waveform start [ns]")
    ax.set_ylabel("Voltage [mV]")
    ax.grid(alpha=0.2)

handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3)
fig.suptitle("12 random matched pairs: digitized real HDF5 vs digitized simulation", y=1.02)
fig.tight_layout()

output_path_adc = OUTPUT_FIGURES / f"{PREFIX}_12_random_pairs_real_adc_vs_sim_adc_start0.png"
save_figure(fig, output_path_adc)
plt.show()

print("Saved analog comparison:", output_path_analog)
print("Saved ADC comparison:", output_path_adc)
print("Selected match_ids:", selected_match_ids.tolist())
# Out:
# Saved analog comparison: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\figures\latest_h5_panel_A_final_digitized_12_random_pairs_real_adc_vs_sim_analog_start0.png
# Saved ADC comparison: c:\Users\jafar\OneDrive\Escritorio\tambo-sipm-framework\tambo-sipm-framework\outputs\figures\latest_h5_panel_A_final_digitized_12_random_pairs_real_adc_vs_sim_adc_start0.png
# Selected match_ids: [3297, 531, 6738, 152, 1738, 1821, 8028, 2520, 5856, 8980, 3438, 2177]
